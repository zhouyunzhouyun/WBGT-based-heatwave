# %%
import matplotlib
import pandas as pd
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt
import numpy as np
import os
# %matplotlib inline  
#内嵌绘图，并且可以省略掉plt.show()这一步
os.chdir('E:\\热浪\\figure')

# %%
#绘图前的基本设置

# myfont = fm.FontProperties(fname=r'C:\Windows\Fonts\Times New Roman.tiff') # 设置字体

# # 设置matplotlib正常显示中文和负号
matplotlib.rcParams['font.sans-serif']=['NSimSun']   # 用黑体显示中文
matplotlib.rcParams['axes.unicode_minus']=False     # 正常显示负号
matplotlib.rcParams['font.size'] = 10.0
matplotlib.rcParams['font.family'] = 'sans-serif'  
matplotlib.rcParams['font.sans-serif'] = 'SimSun,Times NewN Roman'  # NSimSun 新宋体字体   宋体：SimSuncss

# %%
heatwave_wide = data.pivot("year", "地区", "高温均值")
heatwave_wide.head()
# Out:
# 地区        Anhui    Beijing  Chongqing     Fujian      Gansu  Guangdong  \
# year
# 1980  30.477125  25.229308  28.268545  27.916360  23.484933  28.981571
# 1981  29.910963  27.347056  28.443033  28.363238  23.901688  29.201500
# 1982        NaN  25.254667  28.111500  28.025500        NaN  28.813429
# 1983  30.157700  25.950778  27.960400  27.829842  24.000000  28.820143
# 1984  29.646211  25.752133  28.279800  27.848667        NaN  28.780000
#
# 地区      Guangxi    Guizhou     Hainan      Hebei  ...   Shanghai     Shanxi  \
# year                                              ...
# 1980  29.108556  27.554769  28.081143  27.334429  ...  29.184700  26.222714
# 1981  29.040778  27.373867  28.176400  27.888778  ...  28.424455  26.415714
# 1982  28.836739        NaN  28.144900        NaN  ...        NaN        NaN
# 1983  28.963429  27.266556  28.368792  27.729000  ...  28.968625  25.929500
# 1984  28.894167  27.251000        NaN  26.901214  ...  29.074818  25.455000
#
# ...

# %% [markdown]
# # 尝试热浪的点叠加

# %%
data = pd.read_csv('E:\\热浪\\data\\WBGT\\06 分地区分年热浪事件.csv',encoding = 'GBK')

print(data)
# Out:
#       Unnamed: 0  Year  Frequency (times)  Duration(days)  \
# 0              0  1980                  1               6
# 1              1  1981                  4              17
# 2              2  1983                  1               8
# 3              3  1984                  4              16
# 4              4  1985                  1               4
# ...          ...   ...                ...             ...
# 1242        1242  2015                  3              14
# 1243        1243  2016                  4              35
# 1244        1244  2017                  3              43
# 1245        1245  2018                  4              22
# 1246        1246  2019                  1              13
#
#       Average duration (days)  Average WBGTmax (℃) Region  Province  \
# 0                    6.000000            30.477125     EC     Anhui
# 1                    4.250000            29.910963     EC     Anhui
# ...

# %%
# fig, axe = plt.subplots(figsize=(8, 6), dpi=300)
# f, axs = plt.subplots(1, 2, figsize=(8, 4), gridspec_kw=dict(width_ratios=[4, 3]))


cmap =list(["steelblue", "yellowgreen","orange","lightcoral","red", "green","lightskyblue"])
# cmap =list(["#1F78B4", "#B2DF8A","#FDBF6F","#FB9A99","#E31A1C", "#33A02C","#A6CEE3"])

# ax = sns.lineplot(data=data, x="year", y="duration", hue="region",palette=cmap)
sns.lmplot( x="Year", y="Frequency (times)", hue="Region",col="Region",data=data,palette=cmap,col_wrap=7, height=6 ,aspect=.5, x_jitter=.5)
plt.xlabel("Year",fontsize=12,fontweight='bold') 
plt.ylabel("Duration(days)",fontsize=12,fontweight='bold') 
# sns.move_legend(ax, "upper left")
plt.savefig('04 分地区热浪频率时间变化.jpg', dpi=600)
# sns.lmplot(x="total_bill", y="tip", hue="smoker",
#            col="time", row="sex", data=tips);

# %%
cmap =list(["steelblue", "yellowgreen","orange","lightcoral","red", "green","lightskyblue"])
# cmap =list(["#1F78B4", "#B2DF8A","#FDBF6F","#FB9A99","#E31A1C", "#33A02C","#A6CEE3"])


sns.lmplot( x="Year", y="Duration(days)", hue="Region",col="Region",data=data,palette=cmap,col_wrap=7, height=6 ,aspect=.5, x_jitter=.5)


plt.savefig('04 分地区热浪时长变化.jpg',dpi=600)

# %%
cmap =list(["steelblue", "yellowgreen","orange","lightcoral","red", "green","lightskyblue"])
# cmap =list(["#1F78B4", "#B2DF8A","#FDBF6F","#FB9A99","#E31A1C", "#33A02C","#A6CEE3"])


sns.lmplot( x="Year", y="Average duration (days)", hue="Region",col="Region",data=data,palette=cmap,col_wrap=7, height=6 ,aspect=.5, x_jitter=.5)


plt.savefig('04 分地区热浪平均持续时长变化.jpg',dpi=600)

# %%
import seaborn as sns

cmap =list(["steelblue", "yellowgreen","orange","lightcoral","red", "green","lightskyblue"])
# cmap =list(["#1F78B4", "#B2DF8A","#FDBF6F","#FB9A99","#E31A1C", "#33A02C","#A6CEE3"])


# sns.lmplot( x="Year", y="Average WBGTmax (℃)", hue="Region",col="Region",data=data,palette=cmap,col_wrap=7, height=4,aspect=.5, x_jitter=.5)
sns.lmplot( x="Year", y="Avarage WBGTmax (℃) over threshold", hue="Region",col="Region",data=data,palette=cmap,col_wrap=7, height=6 ,aspect=.5, x_jitter=.5)

plt.savefig('04 分地区热浪温度超阈值变化.jpg',dpi=600)

# %%
import seaborn as sns

cmap =list(["steelblue", "yellowgreen","orange","lightcoral","red", "green","lightskyblue"])
# cmap =list(["#1F78B4", "#B2DF8A","#FDBF6F","#FB9A99","#E31A1C", "#33A02C","#A6CEE3"])


# sns.lmplot( x="Year", y="Average WBGTmax (℃)", hue="Region",col="Region",data=data,palette=cmap,col_wrap=7, height=4,aspect=.5, x_jitter=.5)
sns.lmplot( x="Year", y="Cumulative WBGTmax (℃) over threshold", hue="Region",col="Region",data=data,palette=cmap,col_wrap=7, height=6 ,aspect=.5, x_jitter=.5)

plt.savefig('04 分地区累计热浪温度超阈值变化.jpg',dpi=600)

# %%
import seaborn as sns

cmap =list(["steelblue", "yellowgreen","orange","lightcoral","red", "green","lightskyblue"])
# cmap =list(["#1F78B4", "#B2DF8A","#FDBF6F","#FB9A99","#E31A1C", "#33A02C","#A6CEE3"])


# sns.lmplot( x="Year", y="Average WBGTmax (℃)", hue="Region",col="Region",data=data,palette=cmap,col_wrap=7, height=4,aspect=.5, x_jitter=.5)
sns.lmplot( x="Year", y="Heatwave mean degrees over threshold", hue="Region",col="Region",data=data,palette=cmap,col_wrap=7, height=6 ,aspect=.5, x_jitter=.5)

plt.savefig('04 分地区热浪温度超阈值变化.jpg',dpi=600)

# %%
cmap =list(["steelblue", "yellowgreen","orange","lightcoral","red", "green","lightskyblue"])
sns.pairplot(data=data,palette=cmap, hue="Region")
